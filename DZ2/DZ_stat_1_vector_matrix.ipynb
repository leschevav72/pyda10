# %% [markdown]
# # Домашняя работа №1

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt
from scipy import linalg
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
import math

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Изобразите с помощью matplotlib. Изобразите точку x + 2y + 3z. Найдите угол между векторами x, y и x, z.

# %%
x = np.array([1,1])
y = np.array([2, 0])
z = np.array([0,2])
xy=sum([a*b for a,b in zip(x,y)])
x_len=sum([a**2 for a in x])**0.5
y_len=sum([a**2 for a in y])**0.5
z_len=sum([a**2 for a in z])**0.5
XYalpha=math.acos(xy/(x_len*y_len))
xz=sum([a*b for a,b in zip(x,z)])
XZalpha=math.acos(xz/(x_len*z_len))
print('угол между векторами x,y =',XYalpha,'угол между векторами x,z =', XZalpha)
# Out:
# угол между векторами x,y = 0.7853981633974484 угол между векторами x,z = 0.7853981633974484

# %%
m=[1,2,3]
x=list([1])
y=list([2])
z=list([3])
fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')
ax.scatter(x,y,z)

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Найдите собственные значения и собственные вектора матриц (необходимо решение на numpy). Для матрицы 3x3 можно посмотреть на корни характеристического многочлена, посчитанные в numpy.

# %%
m1 = np.array([[2, 2],
               [1, 3]])

m2 = np.array([[4, 1, -1],
               [1, 4, -1],
               [-1, -1, 4]])

# %%
m1_w,m1_v=linalg.eig(m1)
m1_w,m1_v
# Out:
# (array([1.+0.j, 4.+0.j]),
#  array([[-0.89442719, -0.70710678],
#         [ 0.4472136 , -0.70710678]]))

# %%
m2_w,m2_v=linalg.eig(m2)
m2_w,m2_v
# Out:
# (array([3.+0.j, 6.+0.j, 3.+0.j]),
#  array([[-0.81649658,  0.57735027, -0.27658128],
#         [ 0.40824829,  0.57735027,  0.8035929 ],
#         [-0.40824829, -0.57735027,  0.52701162]]))

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Найдите сингулярное разложение матрицы.

# %%
m3 = np.array([[1, 2],
               [2, 3]])

# %%
U, s, V = np.linalg.svd(m3)
s
# Out:
# array([4.23606798, 0.23606798])
