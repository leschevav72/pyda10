# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашняя работа №4

# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
import ssl
# следующая строчка подключает сертификат для защищенного соединения
ssl._create_default_https_context = ssl._create_unverified_context
url='http://yustiks.ru/dataset/housing.csv'
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(url,  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
#посмотрим на значения в столбцах датафрейма, все столбцы, кроме CHAS и RAD , имеют непрерывные велечины, 
#столбцы CHAS и RAD - дискретные
print('RAD: ',data['RAD'].unique())
print('CHAS: ',data['CHAS'].unique())
# Out:
# RAD:  [ 1  2  3  5  4  8  6  7 24]
# CHAS:  [0 1]

# %%
n, bins, patches = plt.hist(data['CRIM'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('CRIM')
plt.title('Частотный график CRIM')
plt.grid(True)
plt.show()
#Экспоненциальное распределение

# %%
n, bins, patches = plt.hist(data['ZN'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('ZN')
plt.title('Частотный график ZN')
plt.grid(True)
plt.show()
#Экспоненциальное распределение

# %%
n, bins, patches = plt.hist(data['INDUS'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('INDUS')
plt.title('Частотный график INDUS')
plt.grid(True)
plt.show()
#Биноминальное распределение

# %%
n, bins, patches = plt.hist(data['CHAS'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('CHAS')
plt.title('Частотный график CHAS')
plt.grid(True)
plt.show()
#распределение Бернулли

# %%
n, bins, patches = plt.hist(data['NOX'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('NOX')
plt.title('Частотный график NOX')
plt.grid(True)
plt.show()
#Логнормальное распределение

# %%
n, bins, patches = plt.hist(data['RM'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('RM')
plt.title('Частотный график RM')
plt.grid(True)
plt.show()
#нормальное распределение

# %%
n, bins, patches = plt.hist(data['AGE'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('AGE')
plt.title('Частотный график AGE')
plt.grid(True)
plt.show()
#обратное экспоненциальное распределение

# %%
n, bins, patches = plt.hist(data['DIS'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('DIS')
plt.title('Частотный график DIS')
plt.grid(True)
plt.show()
#Логнормальное распределение

# %%
n, bins, patches = plt.hist(data['RAD'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('RAD')
plt.title('Частотный график RAD')
plt.grid(True)
plt.show()
#распределение Бернулли

# %%
n, bins, patches = plt.hist(data['PTRATIO'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('PTRATIO')
plt.title('Частотный график PTRATIO')
plt.grid(True)
plt.show()
#обратное логнормальное распределение

# %%
n, bins, patches = plt.hist(data['TAX'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('TAX')
plt.title('Частотный график TAX')
plt.grid(True)
plt.show()
#Биноминальное распределение

# %%
n, bins, patches = plt.hist(data['B'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('B')
plt.title('Частотный график B')
plt.grid(True)
plt.show()
#обратное экспоненциальное распределние

# %%
n, bins, patches = plt.hist(data['LSTAT'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('LSTAT')
plt.title('Частотный график LSTAT')
plt.grid(True)
plt.show()
# Логнормальное распределение

# %%
n, bins, patches = plt.hist(data['MEDV'], 15, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('MEDV')
plt.title('Частотный график MEDV')
plt.grid(True)
plt.show()
#Нормальное распределение

# %%
g = sns.pairplot(data)

# %% [markdown]
# Построить матрицу корреляций для данной таблицы и выбрать максимально коррелирующий атрибут (несколько атрибутов) с ценой на дома (MEDV атрибут).

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) 
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

#максимально коррелирующий с ценой на дома MEDV это атрибут RM с коэффициентом корреляции 0.7

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
# смотрим данные на наличие пропусков (Nan) (data.info()). пропусков нет
#нормальзуем данные в интервале (-1,1)
MEDV = np.array(data['MEDV']).reshape(-1,1)
LSTAT = np.array(data['LSTAT']).reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#делим данные на тестовые (20%) и тренировочные (80%)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    LSTAT, #x
    MEDV, #y
    test_size = 0.2
)

# %%
#обучаем модель
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#предсказание на тестируемых данных. абсолютная и среднеквадратичная ошибки
predicted_y = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print(mean_squared_error(predicted_y, y_test))
print(mean_absolute_error(predicted_y, y_test))
# Out:
# 45.423795431887804
# 4.772174340457543

# %%
plt.ylabel('Статус населения (LSTAT)')
plt.xlabel('Стоимость домов (MEDV)')
plt.title('Линейная регрессия от одной переменной')
# Построим прямую для регрессии
# Создадим 100 точек для предсказаний
x = np.linspace(-1, 50, 10)
# Посчитаем предсказанные значения
# y = kx + b
# k = model.coef_
# b = model.intercept_
y = model.coef_*x + model.intercept_
y = np.transpose(y)
plt.plot(x,y)
plt.plot(X_train, y_train, 'r.')
plt.plot(X_test, y_test, 'g.')
plt.xlim(-1,45)
plt.ylim(-1,45)
plt.legend(['Прямая линейной регрессии', 'Тренировочные данные', 'Тестовые данные'])
plt.show()

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data1=pd.read_csv(url)
data1.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
#df[['Warmmiete__in_€_', 'Preis']].cov()
df=data1.cov()
df.head(10)
# Out:
#                                Ladder  SD of Ladder  Positive affect  \
# Ladder                    2041.000000   1100.838710       995.928571
# SD of Ladder              1100.838710   2041.000000       173.694805
# Positive affect            995.928571    173.694805      2015.000000
# Negative affect           1061.207792   1259.805195       785.240260
# Social support            1657.428571   1219.519481       778.331169
# Freedom                   1108.090909    512.363636      1373.766234
# Corruption                 370.874150    506.897959       405.292517
# Generosity                1008.948052    797.779221       715.077922
# Log of GDP\nper capita    1615.000000   1254.526490       586.120000
# Healthy life\nexpectancy  1613.369128   1208.026846       647.908897
#
#                           Negative affect  Social support      Freedom  \
# Ladder                        1061.207792     1657.428571  1108.090909
# ...

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop).

# %%
data1.info()
#13 отсутствующих значений (Nan), в выборке Country (region) отсутствующих значений нет
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country (region)         156 non-null    object
#  1   Ladder                   156 non-null    int64
#  2   SD of Ladder             156 non-null    int64
#  3   Positive affect          155 non-null    float64
#  4   Negative affect          155 non-null    float64
#  5   Social support           155 non-null    float64
#  6   Freedom                  155 non-null    float64
#  7   Corruption               148 non-null    float64
#  8   Generosity               155 non-null    float64
#  9   Log of GDP
# per capita    152 non-null    float64
#  10  Healthy life
# expectancy  150 non-null    float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 13.5+ KB

# %%
print(data1['Positive affect'].isnull().sum())
print(data1['Country (region)'].isnull().sum())
print(data1[pd.isnull(data1['Corruption'])])
# Out:
# 1
# 0
#          Country (region)  Ladder  SD of Ladder  Positive affect  \
# 20   United Arab Emirates      21            65             43.0
# 27           Saudi Arabia      28            93             49.0
# 28                  Qatar      29            86              NaN
# 36                Bahrain      37            83             39.0
# 50                 Kuwait      51            98             89.0
# 86           Turkmenistan      87             2            135.0
# 92                  China      93            72             21.0
# 100                Jordan     101           127            112.0
#
#      Negative affect  Social support  Freedom  Corruption  Generosity  \
# 20              56.0            72.0      4.0         NaN        15.0
# 27              82.0            62.0     68.0         NaN        82.0
# 28               NaN             NaN      NaN         NaN         NaN
# 36              83.0            59.0     24.0         NaN        23.0
# ...

# %% [markdown]
# Сколько стран в выборке? Написать ответ.

# %%
data1['Country (region)'].nunique()
# Out:
# 156

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы?

# %%
sns.heatmap(data1.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) 
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

#можно увидить сильную и слабую зависимости одного каждого атрибута от других, например видно, 
#что на уровень счастья (Ladder) больше всего влияют социальная поддержка (Social suppor, коэффициент корреляции 0,82), 
#Валовый Внутренний продукт (Log of GDP per capita, коэффициент корреляции 0,81) и продолжительность жизни
#(Healthy life expectancy, коэффициент корреляции 0,82)

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
import random
random.seed()
disc=[1/6,1/6,1/6,1/6,1/6,1/6]
qub = stats.rv_discrete(values=(range(6),disc))
y=qub.rvs(size=10) 
plt.hist(y)

# равномерное распределение
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 3., 0., 4.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
flips_till_heads

# %% [markdown]
# Смоделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. Почему график изменился? Почему можно применить центральную предельную теорему?

# %%
X1 = np.zeros([1000])
for i in range(1000):
    # суммируем все элементы равномерных выборок
    X1[i] = np.sum(stats.geom.rvs(size=100,p=1/6)/100)
plt.hist(X1, 50)
plt.xlabel('X values')
plt.ylabel('Number of elements in each X')
plt.show()

# график изменился, так как мы смотрим распределение 1000 выборных средних значений. ЦПТ применима 
#так как распределение выборных средних соответствует нормальному
